# %%
from aeon.datasets import load_classification
X,Y = load_classification("StandWalkJump")
print(X)
print(Y)
print(X.shape)
print(Y.shape)
print(type(Y))
new_x = X.transpose(0,2,1)
print(new_x.shape)
# Out:
# [[[-0.28 -0.28 -0.27 ... -0.03 -0.04 -0.04]
#   [-0.11 -0.11 -0.11 ...  0.06  0.06  0.08]
#   [ 0.41  0.42  0.43 ... -0.01  0.    0.03]
#   [ 0.59  0.59  0.58 ...  0.04  0.04  0.03]]
#
#  [[-0.13 -0.1  -0.09 ... -0.13 -0.16 -0.18]
#   [-0.09 -0.09 -0.07 ... -0.05 -0.08 -0.12]
#   [ 0.05  0.08  0.11 ... -0.14 -0.15 -0.15]
#   [-0.15 -0.09 -0.07 ... -0.1  -0.1  -0.04]]
#
#  [[-0.01 -0.01 -0.02 ...  0.    0.    0.  ]
#   [ 0.13  0.13  0.15 ...  0.04  0.03  0.05]
#   [-0.11 -0.1  -0.11 ... -0.13 -0.13 -0.13]
#   [-0.07 -0.06 -0.07 ... -0.19 -0.17 -0.17]]
#
#  ...
#
#  [[ 0.2   0.21  0.24 ... -0.71 -0.74 -0.77]
#   [-0.01  0.    0.   ...  1.04  1.08  1.06]
#   [-0.22 -0.22 -0.23 ...  1.66  1.72  1.7 ]
#   [ 0.4   0.42  0.41 ... -1.39 -1.43 -1.44]]
#
#  [[ 0.37  0.39  0.4  ... -0.07 -0.09 -0.1 ]
#   [-0.05 -0.04 -0.04 ... -0.13 -0.14 -0.15]
#   [-0.58 -0.57 -0.58 ...  0.01  0.    0.01]
#   [-0.6  -0.61 -0.64 ...  0.17  0.17  0.18]]
#
#  [[-0.17 -0.17 -0.17 ... -0.33 -0.33 -0.32]
#   [ 0.13  0.19  0.22 ... -2.51 -2.47 -2.41]
#   [-0.15 -0.19 -0.22 ...  3.6   3.55  3.49]
#   [-0.05 -0.03  0.   ... -4.71 -4.64 -4.56]]]
# ['standing' 'standing' 'standing' 'standing' 'walking' 'walking' 'walking'
#  'walking' 'jumping' 'jumping' 'jumping' 'jumping' 'standing' 'standing'
#  'standing' 'standing' 'standing' 'walking' 'walking' 'walking' 'walking'
#  'walking' 'jumping' 'jumping' 'jumping' 'jumping' 'jumping']
# (27, 4, 2500)
# (27,)
# <class 'numpy.ndarray'>
# (27, 2500, 4)

# %%
import numpy as np

# 示例数据
X = np.random.rand(100, 5, 4)  # 假设 X 是一个形状为 (100, 5, 4) 的三维数组
Y = np.random.randint(0, 10, 100)  # 假设标签范围在 0 到 9 之间
print(X)
print(Y)
N = 1
# 获取每种标签的索引
unique_labels, label_counts = np.unique(Y, return_counts=True)

# 初始化用于存储的容器
X_part1 = []
Y_part1 = []
X_part2 = []
Y_part2 = []

# 分别对每种标签进行处理
for label in unique_labels:
    # 获取当前标签的索引
    indices = np.where(Y == label)[0]
    
    # 随机挑选 N 个样本
    selected_indices = np.random.choice(indices, N, replace=False)
    
    # 将这些样本分配给第一部分，其余分配给第二部分
    X_part1.extend(X[selected_indices])
    Y_part1.extend(Y[selected_indices])
    X_part2.extend(X[np.setdiff1d(indices, selected_indices)])
    Y_part2.extend(Y[np.setdiff1d(indices, selected_indices)])

# 转换为 NumPy 数组
X_part1 = np.array(X_part1)
Y_part1 = np.array(Y_part1)
X_part2 = np.array(X_part2)
Y_part2 = np.array(Y_part2)

print("第一部分数据:")
print("X_part1 shape:", X_part1.shape)
print("Y_part1 shape:", Y_part1.shape)

print("\n第二部分数据:")
print("X_part2 shape:", X_part2.shape)
print("Y_part2 shape:", Y_part2.shape)
print(Y_part2)
# Out:
# [[[0.80422147 0.87249506 0.24166862 0.21880925]
#   [0.72633999 0.96654801 0.91741632 0.51116888]
#   [0.61976289 0.90200228 0.06312938 0.11783126]
#   [0.17701596 0.99449965 0.46848228 0.61475877]
#   [0.67072187 0.13413466 0.32687134 0.37508519]]
#
#  [[0.97048604 0.45338805 0.64822865 0.67922188]
#   [0.1008079  0.19093642 0.73410149 0.06551813]
#   [0.7136749  0.09531429 0.40849178 0.39163301]
#   [0.90854821 0.12131092 0.07179471 0.44112235]
#   [0.34047396 0.89740961 0.5108815  0.85284262]]
#
#  [[0.76962541 0.84445989 0.3834961  0.00535507]
#   [0.78322064 0.86202666 0.97910279 0.38086172]
#   [0.24719406 0.25094125 0.08640146 0.14741204]
#   [0.91634662 0.45710648 0.39887369 0.10323705]
#   [0.89738666 0.0607529  0.31984426 0.30968767]]
#
#  ...
#
#  [[0.52767208 0.26770967 0.25939414 0.1151168 ]
#   [0.44714336 0.85928466 0.92693413 0.36840591]
#   [0.37551339 0.69836777 0.60244514 0.5378904 ]
#   [0.22665053 0.04992438 0.00562268 0.18498664]
#   [0.31335357 0.46719418 0.91181877 0.08176688]]
#
#  [[0.6223225  0.10445398 0.91336721 0.97885069]
#   [0.94209446 0.42936782 0.78748375 0.1342561 ]
#   [0.41684919 0.79243896 0.36987085 0.03328902]
#   [0.82183611 0.36264413 0.7338435  0.29223117]
#   [0.24249171 0.02916304 0.37534235 0.29319813]]
#
#  [[0.33851298 0.27974088 0.02495094 0.41876382]
#   [0.64629145 0.33683884 0.27796255 0.59855995]
#   [0.20650992 0.74037451 0.81256328 0.32056014]
#   [0.80597318 0.77294617 0.12251619 0.70221282]
#   [0.00323035 0.70207216 0.40206991 0.4572786 ]]]
# [6 3 9 1 8 6 1 1 4 0 3 9 7 5 9 7 5 0 4 0 1 8 3 9 4 3 7 8 6 0 2 9 5 6 9 8 3
#  8 7 3 7 6 5 5 7 1 8 7 1 6 5 2 0 5 1 3 8 3 2 7 6 3 1 3 7 7 7 8 3 1 4 1 3 7
#  3 1 1 1 2 7 1 7 0 5 2 9 9 3 1 4 8 8 2 5 2 0 0 7 8 4]
# 第一部分数据:
# X_part1 shape: (10, 5, 4)
# Y_part1 shape: (10,)
#
# 第二部分数据:
# X_part2 shape: (90, 5, 4)
# Y_part2 shape: (90,)
